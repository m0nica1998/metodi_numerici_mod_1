# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Lettura dati dal file
data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn30.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn50.dat', sep='\s+', header=None)
# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]

# Impostazione font
font1 = {'family': 'Times New Roman', 'size': 15}
font2 = {'family': 'Times New Roman', 'size': 12}

# Creazione della prima figura
fig, ax1 = plt.subplots()

# Grafico della magnetizzazione su ax1
ax1.set_xlim(-4, 2)
ax1.set_xticks(np.arange(-4, 3, 1))
ax1.minorticks_on()
ax1.errorbar((x-0.440686)*30, y/(30 ** (-1/8)) , yerr=dy/(30 ** (-1/8)), fmt='.', capsize = 2, color='#006699', linewidth=0.5, markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, label='L = 30')
ax1.errorbar((x1-0.440686)*20, y1/(20 ** (-1/8)) , yerr=dy1/(20 ** (-1/8)), fmt='.', capsize = 2, color='green', linewidth=0.5, markerfacecolor='green', markeredgecolor='green', markersize=4, label='L = 20')
ax1.errorbar((x2-0.440686)*40, y2/(40 ** (-1/8)) , yerr=dy2/(40 ** (-1/8)) , fmt='.', capsize = 2, color='purple', linewidth=0.5, markerfacecolor='purple', markeredgecolor='purple', markersize=4, label='L = 40')
ax1.errorbar((x3-0.440686)*50, y3/(50 ** (-1/8)) , yerr=dy3/(50 ** (-1/8)), fmt='.', capsize = 2, color='orange', linewidth=0.5, markerfacecolor='orange', markeredgecolor='orange', markersize=4, label='L = 50')
ax1.legend(loc='best', prop=font2, edgecolor='white')
ax1.set_title('Magnetizzazione F.S.S.\n', fontdict=font1)
ax1.set_xlabel(r'($\beta$-$\beta_c$)L$^{1/\nu}$', fontdict=font2)
ax1.set_ylabel(r'$|M|$/L$^{-\beta/\nu}$', fontdict=font2)
ax1.tick_params(labelsize=10)

data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal30.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal50.dat', sep='\s+', header=None)

# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]

# Creazione della seconda figura
fig, ax2 = plt.subplots()

# Grafico della suscettività su ax2
ax2.set_xlim(-4, 3)
ax2.set_xticks(np.arange(-4, 4, 1))
ax2.set_ylim(0, 12)
ax2.set_yticks(np.arange(0, 13, 2))
ax2.minorticks_on()
ax2.errorbar((x1-0.440686)*20 , y1  , yerr=dy1, fmt='.', capsize = 2, color='green', linewidth=0.5, markerfacecolor='green', markeredgecolor='green', markersize=4, label='L = 20')
ax2.errorbar((x-0.440686)*30, y , yerr=dy, fmt='.', capsize = 2, color='#006699', linewidth=0.5, markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, label='L = 30')
ax2.errorbar((x2-0.440686)*40, y2, yerr=dy2, fmt='.', capsize = 2, color='purple', linewidth=0.5, markerfacecolor='purple', markeredgecolor='purple', markersize=4, label='L = 40')
ax2.errorbar((x3-0.440686)*50, y3, yerr=dy3 , fmt='.', capsize = 2, color='orange', linewidth=0.5, markerfacecolor='orange', markeredgecolor='orange', markersize=4, label='L = 50')
ax2.legend(loc='best', prop=font2, edgecolor='white')
ax2.set_title('Calore specifico F.S.S.\n', fontdict=font1)
ax2.set_xlabel(r'($\beta$-$\beta_c$)L$^{1/\nu} $', fontdict=font2)
ax2.set_ylabel(r'C/L$^{\alpha/\nu}$', fontdict=font2)


ax2.tick_params(labelsize=10)




data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc30.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc50.dat', sep='\s+', header=None)
# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# Estrazione colonne x e y
x = data[0]
y = data[1]
x1 = data1[0]
y1 = data1[1]
x2 = data2[0]
y2 = data2[1]
x3 = data3[0]
y3 = data3[1]

# Creazione della seconda figura
fig, ax3 = plt.subplots()

# Grafico della suscettività su ax2
ax3.set_xlim(-4, 3)
ax3.set_xticks(np.arange(-4, 4, 1))
ax3.minorticks_on()
ax3.errorbar((x1-0.440686)*20, y1/(20 ** (7/4)), yerr=dy1/(20 ** (7/4)), fmt ='.', capsize = 2, color='green', linewidth=0.5, markerfacecolor='green', markeredgecolor='green', markersize=4, label='L = 20')
ax3.errorbar((x-0.440686)*30, y/(30 ** (7/4)), yerr=dy/(30 ** (7/4)), fmt='.', capsize = 2, color='#006699', linewidth=0.5, markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, label='L = 30')
ax3.errorbar((x2-0.440686)*40, y2/(40 ** (7/4)), yerr=dy2/(40 ** (7/4)), fmt='.', capsize = 2, color='purple', linewidth=0.5, markerfacecolor='purple', markeredgecolor='purple', markersize=4, label='L = 40')
ax3.errorbar((x3-0.440686)*50, y3/(50 ** (7/4)), yerr=dy3/(50 ** (7/4)), fmt='.', capsize = 2, color='orange',linewidth=0.5, markerfacecolor='orange', markeredgecolor='orange', markersize=4, label='L = 50')
ax3.legend(loc='best', prop=font2, edgecolor='white')
ax3.set_title('Suscettività magnetica F.S.S.\n', fontdict=font1)
ax3.set_xlabel(r'($\beta$-$\beta_c$)L$^{1/\nu}$', fontdict=font2)
ax3.set_ylabel(r'$\chi$/L$^{\gamma/\nu}$', fontdict=font2)

ax3.tick_params(labelsize=10)




# Visualizzazione del plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Lettura dati dal file
data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn30.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn50.dat', sep='\s+', header=None)
# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]

# Impostazione font
font1 = {'family': 'Times New Roman', 'size': 15}
font2 = {'family': 'Times New Roman', 'size': 12}


# Creazione della prima figura
fig, ax1 = plt.subplots()

# Grafico della magnetizzazione su ax1
ax1.set_xlim(0.34, 0.5)
ax1.set_xticks(np.arange(0.34, 0.52, 0.02))
ax1.set_ylim(0, 1)
ax1.set_yticks(np.arange(0, 1.2, 0.2))
ax1.minorticks_on()
ax1.errorbar(x1, y1, yerr=dy1, fmt= '.', capsize = 2,color='green', markerfacecolor='green', markeredgecolor='green', markersize=4, linewidth=0.5, label='L = 20')
ax1.errorbar(x, y, yerr=dy, fmt ='.', capsize = 2, color='#006699', markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, linewidth=0.5, label='L = 30')
ax1.errorbar(x2, y2, yerr=dy2, fmt= '.', capsize = 2, color='purple', markerfacecolor='purple', markeredgecolor='purple', markersize=4, linewidth=0.5, label='L = 40')
ax1.errorbar(x3, y3, yerr=dy3, fmt='.', capsize = 2, color='orange', markerfacecolor='orange', markeredgecolor='orange', markersize=4, linewidth=0.5, label='L = 50')
ax1.legend(loc='best', prop=font2, edgecolor='white')
ax1.set_title('Magnetizzazione intorno alla transizione per diversi volumi\n', fontdict=font1)
ax1.set_xlabel(r'$\beta$', fontdict=font2)
ax1.tick_params(labelsize=10)

data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal25.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_cal50.dat', sep='\s+', header=None)

# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]

# Creazione della seconda figura
fig, ax2 = plt.subplots()

# Grafico del calore specifico su ax2
ax2.set_xlim(0.38, 0.48)
ax2.set_xticks(np.arange(0.34, 0.5, 0.02))
ax2.set_ylim(0, 12)
ax2.set_yticks(np.arange(0, 14, 2))
ax2.minorticks_on()
ax2.errorbar(x1, y1, yerr=dy1, fmt='.',capsize=2, color='green', markerfacecolor='green', markeredgecolor='green', markersize=4, linewidth=0.5, label='L = 20')
ax2.errorbar(x, y, yerr=dy, fmt= '.', capsize=2, color='#006699', markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, linewidth=0.5, label='L = 30')
ax2.errorbar(x2, y2, yerr=dy2, fmt= '.', capsize=2, color='purple',markerfacecolor='purple', markeredgecolor='purple', markersize=4, linewidth=0.5, label='L = 40')
ax2.errorbar(x3, y3, yerr=dy3,fmt= '.', capsize=2, color='orange',markerfacecolor='orange', markeredgecolor='orange', markersize=4, linewidth=0.5, label='L = 50')
ax2.legend(loc='best', prop=font2, edgecolor='white')
ax2.set_title('Calore specifico intorno alla transizione per diversi volumi\n', fontdict=font1)
ax2.set_xlabel(r'$\beta$', fontdict=font2)
ax2.tick_params(labelsize=10)


data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc25.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_susc50.dat', sep='\s+', header=None)
# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]

# Creazione della seconda figura
fig, ax3 = plt.subplots()

# Grafico della suscettività su ax2
ax3.set_xlim(0.34, 0.5)
ax3.set_xticks(np.arange(0.34, 0.52, 0.02))
ax3.set_ylim(0, 120)
ax3.set_yticks(np.arange(0, 120, 20))
ax3.minorticks_on()
ax3.errorbar(x1, y1, yerr=dy1, fmt='.', color='green', capsize = 2, markerfacecolor='green', markeredgecolor='green', markersize=4, linewidth=0.5, label='L = 20')
ax3.errorbar(x, y, yerr=dy, fmt='.', color='#006699', capsize = 2,markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, linewidth=0.5, label='L = 30')
ax3.errorbar(x2, y2, yerr=dy2, fmt='.', color='purple', capsize = 2, markerfacecolor='purple', markeredgecolor='purple', markersize=4, linewidth=0.5, label='L = 40')
ax3.errorbar(x3, y3, yerr=dy3, fmt='.', color='orange', capsize = 2, markerfacecolor='orange', markeredgecolor='orange', markersize=4, linewidth=0.5, label='L = 50')
ax3.legend(loc='best', prop=font2, edgecolor='white')
ax3.set_title('Suscettività magnetica intorno alla transizione per diversi volumi\n', fontdict=font1)
ax3.set_xlabel(r'$\beta$', fontdict=font2)
ax3.tick_params(labelsize=10)



# Visualizzazione del plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Lettura dati dal file
data = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn30.dat', sep='\s+', header=None)
data1 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn20.dat', sep='\s+', header=None)
data2 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn40.dat', sep='\s+', header=None)
data3 = pd.read_csv('/Users/monicacesario/Desktop/modulo1/term_magn50.dat', sep='\s+', header=None)
# Creazione dataframe
data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)
data2 = pd.DataFrame(data2)
data3 = pd.DataFrame(data3)

# Estrazione colonne x e y
x = data[0]
y = data[1]
dy = data[2]

x1 = data1[0]
y1 = data1[1]
dy1 = data1[2]

x2 = data2[0]
y2 = data2[1]
dy2 = data2[2]

x3 = data3[0]
y3 = data3[1]
dy3 = data3[2]


# Impostazione font
font1 = {'family': 'Times New Roman', 'size': 15}
font2 = {'family': 'Times New Roman', 'size': 12}

# Creazione della prima figura
fig, ax1 = plt.subplots()

# Grafico della magnetizzazione su ax1
ax1.set_xlim(-4, 2)
ax1.set_xticks(np.arange(-4, 3, 1))
ax1.minorticks_on()
ax1.errorbar((x-0.440686)*30, y/(30 ** (-1/8)) , yerr=dy/(30 ** (-1/8)), fmt='.', capsize = 2, color='#006699', linewidth=0.5, markerfacecolor='#006699', markeredgecolor='#006699', markersize=4, label='L = 30')
ax1.errorbar((x1-0.440686)*20, y1/(20 ** (-1/8)) , yerr=dy1/(20 ** (-1/8)), fmt='.', capsize = 2, color='green', linewidth=0.5, markerfacecolor='green', markeredgecolor='green', markersize=4, label='L = 20')
ax1.errorbar((x2-0.440686)*40, y2/(40 ** (-1/8)) , yerr=dy2/(40 ** (-1/8)) , fmt='.', capsize = 2, color='purple', linewidth=0.5, markerfacecolor='purple', markeredgecolor='purple', markersize=4, label='L = 40')
ax1.errorbar((x3-0.440686)*50, y3/(50 ** (-1/8)) , yerr=dy3/(50 ** (-1/8)), fmt='.', capsize = 2, color='orange', linewidth=0.5, markerfacecolor='orange', markeredgecolor='orange', markersize=4, label='L = 50')
ax1.legend(loc='best', prop=font2, edgecolor='white')
ax1.set_title('Magnetizzazione F.S.S.\n', fontdict=font1)
ax1.set_xlabel(r'($\beta$-$\beta_c$)L$^{1/\nu}$', fontdict=font2)
ax1.set_ylabel(r'$|M|$/L$^{-\beta/\nu}$', fontdict=font2)
ax1.tick_params(labelsize=10)
plt.show()
